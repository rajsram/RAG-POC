# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

print("✅ Embeddings working!")
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_42220\1934629405.py:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# ✅ Embeddings working!

# %%
# Install required packages first:
# pip install langchain langchain-community langchain-huggingface faiss-cpu sentence-transformers pypdf docx2txt

from langchain_community.document_loaders import TextLoader, PyPDFLoader, Docx2txtLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings 
from langchain_community.llms import Ollama
import os

# =========================
# 1. LOAD FILE (AUTO DETECT)
# =========================
file_path = "C:/Users/Dell/Downloads/Nature.pdf"   # change to your file (.txt / .pdf / .docx)

if file_path.endswith(".txt"):
    loader = TextLoader(file_path)

elif file_path.endswith(".pdf"):
    loader = PyPDFLoader(file_path)

elif file_path.endswith(".docx"):
    loader = Docx2txtLoader(file_path)

else:
    raise ValueError("Unsupported file type")

documents = loader.load()

# =========================
# 2. SPLIT TEXT
# =========================
splitter = CharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)
docs = splitter.split_documents(documents)

# =========================
# 3. EMBEDDINGS (FIXED VERSION)
# =========================
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# =========================
# 4. VECTOR DATABASE
# =========================
db = FAISS.from_documents(docs, embeddings)

# =========================
# 5. LOAD LLM (OLLAMA)
# =========================
#  # make sure: ollama run llama3
#llm = Ollama(model="phi")
llm = Ollama(model="tinyllama")
# =========================
# 6. QUESTION LOOP
# =========================
print("\n✅ System Ready! Ask your questions (type 'exit' to quit)\n")

while True:
    query = input("👉 Question: ")

    if query.lower() == "exit":
        print("Goodbye!")
        break

    # =========================
    # 7. RETRIEVE CONTEXT (RAG)
    # =========================
    retrieved_docs = db.similarity_search(query)
    context = " ".join([doc.page_content for doc in retrieved_docs])

    # =========================
    # 8. PROMPT
    # =========================
    prompt = f"""
    You are an AI assistant.

    Answer ONLY using the context below.
    If the answer is not in the context, say "I don't know".

    Context:
    {context}

    Question:
    {query}

    Answer:
    """

    # =========================
    # 9. GENERATE RESPONSE
    # =========================
    response = llm.invoke(prompt)

    print("\n💡 Answer:", response)
# Out:
# ✅ System Ready! Ask your questions (type 'exit' to quit)
# 👉 Question:  Tell me about nature
# 💡 Answer: Yes, I can provide an answer using the given context. Nature encompases all living organisms, ecosystems, and physical features of the Earth created by humans. It provides oxygen, food, water, climate regulation, and significant physical and mental health benefits. However, human activity threatens these systems and affects the balance required for a sustainable planet.
# 👉 Question:  exit
# Goodbye!

# %%
from langchain_community.llms import Ollama

# Load LLM
llm = Ollama(model="tinyllama")

print("🤖 Chatbot Ready! (type 'exit' to quit)")

while True:
    user_input = input("\nYou: ")

    if user_input.lower() == "exit":
        break

    # Direct prompt (no NLP, no retrieval)
    response = llm.invoke(user_input)

    print("Bot:", response)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2260\143775603.py:4: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="tinyllama")
# 🤖 Chatbot Ready! (type 'exit' to quit)
# You:  what is Nature
# Bot: Nature is the name of the operating system developed by Google. It's a customized version of Linux that was designed to offer more advanced functionality and features for use on Google-owned devices such as smartphones, tablets, laptops, and desktops. The OS also includes support for Google's various applications and services, such as Chrome, Gmail, Google Drive, and Google Maps, which are all designed to work well together within the Nature environment. Additionally, Nature can be customized by the user in many ways, allowing them to tailor their experience to fit their specific needs and preferences.
# You:  explain about flower Rose
# Bot: Certainly! Flower Rose is one of the most popular flowers in the world and has been cultivated for centuries for its beauty, fragrance, and medicinal properties. Here's a detailed explination on why it is such a beloved flower:
#
# 1. Beauty - Rose blooms are known for their stunning beauty. They have long, delicate petals that are covered in delicate white or pink petals, giving the flower a feminine and elegant appearance. The fragrance of a freshly opened rose bouquet is also said to be captivating and captivating.
#
# 2. Fragrance - Rose scent is one of its most significant appeals. Its distinctive blend of floral aromas, including lilac, jasmine, and heliotrope, makes the flower's fragrance exquisite and enticing to many. The oil from the petals has been used for centuries as an antiseptic, tonic, and aphrodisiac, making Rose's fragrance one of its most sought-after properties.
#
# 3. Medicinal Properties - Rose contains several active ingredients that have been shown to possess medicinal properties such as anti-inflammatory, antibacterial, and antiviral effects. Its rich oil content is derived from the seeds or petals of the Rosa Damascena, which are known for their high level of essential oils.
#
# 4. Cultural Significance - The beauty, fragrance, and medicinal properties of Rose have made it a popular flower in many cultures worldwide. Its association with love and romance has made Rose a symbol of romanticism and passion. In China, it is believed to bring good luck and happiness.
#
# In conclusion, Flower Rose is indeed one of the most beloved flowers throughout history, thanks to its beauty, fragrance, medicinal properties, cultural significance, and timeless appeal that make it a favorite among people worldwide.
# You:  exit
